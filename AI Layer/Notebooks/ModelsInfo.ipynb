# %% [markdown]
# # YOLO Model Inspector
# This notebook displays detailed information about a YOLO model including:
# - Model architecture
# - Class labels/names
# - Input size
# - Number of parameters
# - Layer information

# %%
from ultralytics import YOLO
import torch

# Change this to your model path
MODEL_PATH = "../Models/Car Accident.pt"  # Update this path to your model

# %%
# Load the model
model = YOLO(MODEL_PATH)
print(f"✅ Model loaded successfully from: {MODEL_PATH}")
# Out:
# ✅ Model loaded successfully from: ../Models/Car Accident.pt

# %% [markdown]
# ## Class Labels / Names
# The classes this model can detect:

# %%
# Get class names/labels
class_names = model.names
print(f"📋 Number of classes: {len(class_names)}\n")
print("Class ID -> Class Name:")
print("-" * 30)
for class_id, class_name in class_names.items():
    print(f"  {class_id:3d} -> {class_name}")
# Out:
# 📋 Number of classes: 3
#
# Class ID -> Class Name:
# ------------------------------
#     0 -> accident
#     1 -> person
#     2 -> vehicle

# %% [markdown]
# ## Model Information
# General model details and architecture:

# %%
# Model info
print("🔧 MODEL INFORMATION")
print("=" * 50)
print(f"Task:          {model.task}")
print(f"Model Type:    {type(model.model).__name__}")
print(f"Device:        {'CUDA' if torch.cuda.is_available() else 'CPU'}")

# Get model parameters count
total_params = sum(p.numel() for p in model.model.parameters())
trainable_params = sum(p.numel() for p in model.model.parameters() if p.requires_grad)

print(f"\n📊 PARAMETERS")
print("-" * 50)
print(f"Total Parameters:     {total_params:,}")
print(f"Trainable Parameters: {trainable_params:,}")
print(f"Model Size (MB):      {total_params * 4 / (1024**2):.2f}")
# Out:
# 🔧 MODEL INFORMATION
# ==================================================
# Task:          detect
# Model Type:    DetectionModel
# Device:        CPU
#
# 📊 PARAMETERS
# --------------------------------------------------
# Total Parameters:     11,136,761
# Trainable Parameters: 0
# Model Size (MB):      42.48
# /home/ziadmoh/Programs/anaconda3/envs/AI_ENV/lib/python3.11/site-packages/torch/cuda/__init__.py:182: UserWarning: CUDA initialization: CUDA unknown error - this may be due to an incorrectly set up environment, e.g. changing env variable CUDA_VISIBLE_DEVICES after program start. Setting the available devices to be zero. (Triggered internally at /pytorch/c10/cuda/CUDAFunctions.cpp:119.)
#   return torch._C._cuda_getDeviceCount() > 0

# %% [markdown]
# ## Input / Output Details

# %%
# Input/Output details from model args
print("📥 INPUT/OUTPUT DETAILS")
print("=" * 50)

# Try to get model arguments
if hasattr(model.model, 'args'):
    args = model.model.args
    print(f"Input Size (imgsz): {args.get('imgsz', 'N/A')}")
    print(f"Batch Size:         {args.get('batch', 'N/A')}")
    
# Get stride info
if hasattr(model.model, 'stride'):
    print(f"Stride:             {model.model.stride}")

# Number of classes from model head
if hasattr(model.model, 'nc'):
    print(f"Number of Classes:  {model.model.nc}")
# Out:
# 📥 INPUT/OUTPUT DETAILS
# ==================================================
# Input Size (imgsz): 640
# Batch Size:         N/A
# Stride:             tensor([ 8., 16., 32.])
# Number of Classes:  3

# %% [markdown]
# ## Model Architecture (Layers)

# %%
# Print model architecture summary
print("🏗️ MODEL ARCHITECTURE")
print("=" * 50)
model.info(detailed=False)
# Out:
# 🏗️ MODEL ARCHITECTURE
# ==================================================
# Model summary: 129 layers, 11,136,761 parameters, 0 gradients, 28.7 GFLOPs
# (129, 11136761, 0, 28.651263999999998)

# %% [markdown]
# ## Complete Model Summary (All Layers)

# %%
# Detailed layer-by-layer breakdown
print("📜 DETAILED LAYER INFO")
print("=" * 70)
model.info(detailed=True, verbose=True)
# Out:
# 📜 DETAILED LAYER INFO
# ======================================================================
# layer                                    name                type  gradient  parameters               shape        mu     sigma
#     0                     model.0.conv.weight              Conv2d     False         864       [32, 3, 3, 3]    0.0118     0.408        float32
#     1                       model.0.bn.weight         BatchNorm2d     False          32                [32]      2.63      1.47        float32
#     1                         model.0.bn.bias         BatchNorm2d     False          32                [32]     -2.53      5.64        float32
#     2                             model.0.act                SiLU     False           0                  []         -         -              -
#     3                     model.1.conv.weight              Conv2d     False       18432      [64, 32, 3, 3]  -0.00153     0.403        float32
#     4                       model.1.bn.weight         BatchNorm2d     False          64                [64]       3.5     0.982        float32
#     4                         model.1.bn.bias         BatchNorm2d     False          64                [64]     0.172      1.56        float32
#     5                 model.2.cv1.conv.weight              Conv2d     False        4096      [64, 64, 1, 1]    -0.102     0.584        float32
#     6                   model.2.cv1.bn.weight         BatchNorm2d     False          64                [64]      2.03      1.01        float32
#     6                     model.2.cv1.bn.bias         BatchNorm2d     False          64                [64]     0.324      1.62        float32
#     7                 model.2.cv2.conv.weight              Conv2d     False        6144      [64, 96, 1, 1]   -0.0676     0.552        float32
#     8                   model.2.cv2.bn.weight         BatchNorm2d     False          64                [64]       1.5     0.381        float32
#     8                     model.2.cv2.bn.bias         BatchNorm2d     False          64                [64]    -0.347      1.19        float32
#     9             model.2.m.0.cv1.conv.weight              Conv2d     False        9216      [32, 32, 3, 3]     -0.04      0.53        float32
#    10               model.2.m.0.cv1.bn.weight         BatchNorm2d     False          32                [32]      2.36      0.67        float32
#    10                 model.2.m.0.cv1.bn.bias         BatchNorm2d     False          32                [32]    0.0883      2.19        float32
#    11             model.2.m.0.cv2.conv.weight              Conv2d     False        9216      [32, 32, 3, 3]   -0.0375     0.536        float32
#    12               model.2.m.0.cv2.bn.weight         BatchNorm2d     False          32                [32]      2.15     0.606        float32
#    12                 model.2.m.0.cv2.bn.bias         BatchNorm2d     False          32                [32]     0.705      2.33        float32
#    13                     model.3.conv.weight              Conv2d     False       73728     [128, 64, 3, 3]   -0.0367     0.501        float32
#    14                       model.3.bn.weight         BatchNorm2d     False         128               [128]      1.08     0.226        float32
#    14                         model.3.bn.bias         BatchNorm2d     False         128               [128]     -0.51      1.12        float32
#    15                 model.4.cv1.conv.weight              Conv2d     False       16384    [128, 128, 1, 1]   -0.0487     0.531        float32
#    16                   model.4.cv1.bn.weight         BatchNorm2d     False         128               [128]      1.08     0.461        float32
#    16                     model.4.cv1.bn.bias         BatchNorm2d     False         128               [128]    -0.041      1.17        float32
#    17                 model.4.cv2.conv.weight              Conv2d     False       32768    [128, 256, 1, 1]   -0.0584     0.523        float32
#    18                   model.4.cv2.bn.weight         BatchNorm2d     False         128               [128]      1.27     0.261        float32
#    18                     model.4.cv2.bn.bias         BatchNorm2d     False         128               [128]      -0.6      1.04        float32
#    19             model.4.m.0.cv1.conv.weight              Conv2d     False       36864      [64, 64, 3, 3]   -0.0517     0.527        float32
#    20               model.4.m.0.cv1.bn.weight         BatchNorm2d     False          64                [64]      1.15     0.215        float32
#    20                 model.4.m.0.cv1.bn.bias         BatchNorm2d     False          64                [64]     -1.15      0.97        float32
#    21             model.4.m.0.cv2.conv.weight              Conv2d     False       36864      [64, 64, 3, 3]    -0.046     0.536        float32
#    22               model.4.m.0.cv2.bn.weight         BatchNorm2d     False          64                [64]      1.19     0.237        float32
#    22                 model.4.m.0.cv2.bn.bias         BatchNorm2d     False          64                [64]    -0.426     0.638        float32
#    23             model.4.m.1.cv1.conv.weight              Conv2d     False       36864      [64, 64, 3, 3]   -0.0544     0.532        float32
#    24               model.4.m.1.cv1.bn.weight         BatchNorm2d     False          64                [64]     0.977     0.136        float32
#    24                 model.4.m.1.cv1.bn.bias         BatchNorm2d     False          64                [64]      -1.5     0.766        float32
#    25             model.4.m.1.cv2.conv.weight              Conv2d     False       36864      [64, 64, 3, 3]    -0.032     0.515        float32
#    26               model.4.m.1.cv2.bn.weight         BatchNorm2d     False          64                [64]      1.71      0.33        float32
#    26                 model.4.m.1.cv2.bn.bias         BatchNorm2d     False          64                [64]     0.402      1.29        float32
#    27                     model.5.conv.weight              Conv2d     False      294912    [256, 128, 3, 3]   -0.0251     0.488        float32
#    28                       model.5.bn.weight         BatchNorm2d     False         256               [256]      1.28     0.247        float32
#    28                         model.5.bn.bias         BatchNorm2d     False         256               [256]    -0.957     0.946        float32
#    29                 model.6.cv1.conv.weight              Conv2d     False       65536    [256, 256, 1, 1]   -0.0649       0.5        float32
#    30                   model.6.cv1.bn.weight         BatchNorm2d     False         256               [256]      1.26     0.432        float32
#    30                     model.6.cv1.bn.bias         BatchNorm2d     False         256               [256]     -0.68     0.979        float32
#    31                 model.6.cv2.conv.weight              Conv2d     False      131072    [256, 512, 1, 1]   -0.0529     0.493        float32
#    32                   model.6.cv2.bn.weight         BatchNorm2d     False         256               [256]      1.33      0.34        float32
#    32                     model.6.cv2.bn.bias         BatchNorm2d     False         256               [256]    -0.996      1.08        float32
#    33             model.6.m.0.cv1.conv.weight              Conv2d     False      147456    [128, 128, 3, 3]   -0.0616     0.528        float32
#    34               model.6.m.0.cv1.bn.weight         BatchNorm2d     False         128               [128]      1.37     0.154        float32
#    34                 model.6.m.0.cv1.bn.bias         BatchNorm2d     False         128               [128]     -1.92     0.727        float32
#    35             model.6.m.0.cv2.conv.weight              Conv2d     False      147456    [128, 128, 3, 3]   -0.0471     0.562        float32
#    36               model.6.m.0.cv2.bn.weight         BatchNorm2d     False         128               [128]      1.46     0.252        float32
#    36                 model.6.m.0.cv2.bn.bias         BatchNorm2d     False         128               [128]    -0.688     0.682        float32
#    37             model.6.m.1.cv1.conv.weight              Conv2d     False      147456    [128, 128, 3, 3]    -0.055     0.563        float32
#    38               model.6.m.1.cv1.bn.weight         BatchNorm2d     False         128               [128]      1.26     0.161        float32
#    38                 model.6.m.1.cv1.bn.bias         BatchNorm2d     False         128               [128]     -2.12     0.862        float32
#    39             model.6.m.1.cv2.conv.weight              Conv2d     False      147456    [128, 128, 3, 3]   -0.0279     0.532        float32
#    40               model.6.m.1.cv2.bn.weight         BatchNorm2d     False         128               [128]      2.26     0.325        float32
#    40                 model.6.m.1.cv2.bn.bias         BatchNorm2d     False         128               [128]     -0.26      1.22        float32
#    41                     model.7.conv.weight              Conv2d     False 1.17965e+06    [512, 256, 3, 3]   -0.0266      0.37        float32
#    42                       model.7.bn.weight         BatchNorm2d     False         512               [512]      1.41     0.441        float32
#    42                         model.7.bn.bias         BatchNorm2d     False         512               [512]     -0.89      1.06        float32
#    43                 model.8.cv1.conv.weight              Conv2d     False      262144    [512, 512, 1, 1]   -0.0522     0.329        float32
#    44                   model.8.cv1.bn.weight         BatchNorm2d     False         512               [512]      1.05     0.383        float32
#    44                     model.8.cv1.bn.bias         BatchNorm2d     False         512               [512]    -0.894      1.41        float32
#    45                 model.8.cv2.conv.weight              Conv2d     False      393216    [512, 768, 1, 1]   -0.0435     0.332        float32
#    46                   model.8.cv2.bn.weight         BatchNorm2d     False         512               [512]      1.56     0.439        float32
#    46                     model.8.cv2.bn.bias         BatchNorm2d     False         512               [512]    -0.554      1.24        float32
#    47             model.8.m.0.cv1.conv.weight              Conv2d     False      589824    [256, 256, 3, 3]   -0.0142     0.321        float32
#    48               model.8.m.0.cv1.bn.weight         BatchNorm2d     False         256               [256]      1.55       0.4        float32
#    48                 model.8.m.0.cv1.bn.bias         BatchNorm2d     False         256               [256]     -1.36      1.28        float32
#    49             model.8.m.0.cv2.conv.weight              Conv2d     False      589824    [256, 256, 3, 3]    -0.027     0.346        float32
#    50               model.8.m.0.cv2.bn.weight         BatchNorm2d     False         256               [256]      2.12     0.594        float32
#    50                 model.8.m.0.cv2.bn.bias         BatchNorm2d     False         256               [256]    -0.622      1.37        float32
#    51                 model.9.cv1.conv.weight              Conv2d     False      131072    [256, 512, 1, 1]   -0.0954     0.406        float32
#    52                   model.9.cv1.bn.weight         BatchNorm2d     False         256               [256]       1.2      0.43        float32
#    52                     model.9.cv1.bn.bias         BatchNorm2d     False         256               [256]    0.0774      1.14        float32
#    53                 model.9.cv2.conv.weight              Conv2d     False      524288   [512, 1024, 1, 1]   -0.0059     0.429        float32
#    54                   model.9.cv2.bn.weight         BatchNorm2d     False         512               [512]      1.34     0.335        float32
#    54                     model.9.cv2.bn.bias         BatchNorm2d     False         512               [512]     -2.06      1.16        float32
#    55                               model.9.m           MaxPool2d     False           0                  []         -         -              -
#    56                                model.10            Upsample     False           0                  []         -         -              -
#    57                                model.11              Concat     False           0                  []         -         -              -
#    58                model.12.cv1.conv.weight              Conv2d     False      196608    [256, 768, 1, 1]   -0.0406      0.51        float32
#    59                  model.12.cv1.bn.weight         BatchNorm2d     False         256               [256]      1.37     0.357        float32
#    59                    model.12.cv1.bn.bias         BatchNorm2d     False         256               [256]     -1.28      1.32        float32
#    60                model.12.cv2.conv.weight              Conv2d     False       98304    [256, 384, 1, 1]   -0.0687     0.482        float32
#    61                  model.12.cv2.bn.weight         BatchNorm2d     False         256               [256]      1.06     0.214        float32
#    61                    model.12.cv2.bn.bias         BatchNorm2d     False         256               [256]     -1.43      1.22        float32
#    62            model.12.m.0.cv1.conv.weight              Conv2d     False      147456    [128, 128, 3, 3]    -0.042     0.503        float32
#    63              model.12.m.0.cv1.bn.weight         BatchNorm2d     False         128               [128]      1.28     0.195        float32
#    63                model.12.m.0.cv1.bn.bias         BatchNorm2d     False         128               [128]     -1.75      1.26        float32
#    64            model.12.m.0.cv2.conv.weight              Conv2d     False      147456    [128, 128, 3, 3]   -0.0402     0.485        float32
#    65              model.12.m.0.cv2.bn.weight         BatchNorm2d     False         128               [128]      1.43     0.211        float32
#    65                model.12.m.0.cv2.bn.bias         BatchNorm2d     False         128               [128]    -0.516       1.2        float32
#    66                                model.13            Upsample     False           0                  []         -         -              -
#    67                                model.14              Concat     False           0                  []         -         -              -
#    68                model.15.cv1.conv.weight              Conv2d     False       49152    [128, 384, 1, 1]   -0.0562     0.506        float32
#    69                  model.15.cv1.bn.weight         BatchNorm2d     False         128               [128]     0.933     0.285        float32
#    69                    model.15.cv1.bn.bias         BatchNorm2d     False         128               [128]    -0.659      1.09        float32
#    70                model.15.cv2.conv.weight              Conv2d     False       24576    [128, 192, 1, 1]   -0.0562     0.487        float32
#    71                  model.15.cv2.bn.weight         BatchNorm2d     False         128               [128]     0.839     0.277        float32
#    71                    model.15.cv2.bn.bias         BatchNorm2d     False         128               [128]    -0.615      1.02        float32
#    72            model.15.m.0.cv1.conv.weight              Conv2d     False       36864      [64, 64, 3, 3]   -0.0549     0.515        float32
#    73              model.15.m.0.cv1.bn.weight         BatchNorm2d     False          64                [64]      0.96     0.161        float32
#    73                model.15.m.0.cv1.bn.bias         BatchNorm2d     False          64                [64]    -0.974     0.939        float32
#    74            model.15.m.0.cv2.conv.weight              Conv2d     False       36864      [64, 64, 3, 3]    -0.038     0.479        float32
#    75              model.15.m.0.cv2.bn.weight         BatchNorm2d     False          64                [64]      1.17     0.247        float32
#    75                model.15.m.0.cv2.bn.bias         BatchNorm2d     False          64                [64]    -0.126      1.09        float32
#    76                    model.16.conv.weight              Conv2d     False      147456    [128, 128, 3, 3]   -0.0118      0.42        float32
#    77                      model.16.bn.weight         BatchNorm2d     False         128               [128]      1.24     0.314        float32
#    77                        model.16.bn.bias         BatchNorm2d     False         128               [128]    -0.971     0.878        float32
#    78                                model.17              Concat     False           0                  []         -         -              -
#    79                model.18.cv1.conv.weight              Conv2d     False       98304    [256, 384, 1, 1]   -0.0424     0.392        float32
#    80                  model.18.cv1.bn.weight         BatchNorm2d     False         256               [256]     0.967     0.303        float32
#    80                    model.18.cv1.bn.bias         BatchNorm2d     False         256               [256]    -0.953      1.37        float32
#    81                model.18.cv2.conv.weight              Conv2d     False       98304    [256, 384, 1, 1]   -0.0597     0.381        float32
#    82                  model.18.cv2.bn.weight         BatchNorm2d     False         256               [256]      1.03     0.441        float32
#    82                    model.18.cv2.bn.bias         BatchNorm2d     False         256               [256]     -1.37      1.36        float32
#    83            model.18.m.0.cv1.conv.weight              Conv2d     False      147456    [128, 128, 3, 3]   -0.0478     0.424        float32
#    84              model.18.m.0.cv1.bn.weight         BatchNorm2d     False         128               [128]      1.14     0.314        float32
#    84                model.18.m.0.cv1.bn.bias         BatchNorm2d     False         128               [128]     -1.35      1.18        float32
#    85            model.18.m.0.cv2.conv.weight              Conv2d     False      147456    [128, 128, 3, 3]   -0.0349     0.427        float32
#    86              model.18.m.0.cv2.bn.weight         BatchNorm2d     False         128               [128]      1.73     0.342        float32
#    86                model.18.m.0.cv2.bn.bias         BatchNorm2d     False         128               [128]    -0.567      1.04        float32
#    87                    model.19.conv.weight              Conv2d     False      589824    [256, 256, 3, 3]  -0.00442     0.299        float32
#    88                      model.19.bn.weight         BatchNorm2d     False         256               [256]      1.03     0.413        float32
#    88                        model.19.bn.bias         BatchNorm2d     False         256               [256]     -1.03     0.919        float32
#    89                                model.20              Concat     False           0                  []         -         -              -
#    90                model.21.cv1.conv.weight              Conv2d     False      393216    [512, 768, 1, 1]   -0.0179     0.321        float32
#    91                  model.21.cv1.bn.weight         BatchNorm2d     False         512               [512]      1.03     0.382        float32
#    91                    model.21.cv1.bn.bias         BatchNorm2d     False         512               [512]     -1.41       1.2        float32
#    92                model.21.cv2.conv.weight              Conv2d     False      393216    [512, 768, 1, 1]   -0.0378     0.286        float32
#    93                  model.21.cv2.bn.weight         BatchNorm2d     False         512               [512]      1.21     0.546        float32
#    93                    model.21.cv2.bn.bias         BatchNorm2d     False         512               [512]     -1.41       1.4        float32
#    94            model.21.m.0.cv1.conv.weight              Conv2d     False      589824    [256, 256, 3, 3]    -0.022     0.304        float32
#    95              model.21.m.0.cv1.bn.weight         BatchNorm2d     False         256               [256]      1.28     0.402        float32
#    95                model.21.m.0.cv1.bn.bias         BatchNorm2d     False         256               [256]     -1.56      1.21        float32
#    96            model.21.m.0.cv2.conv.weight              Conv2d     False      589824    [256, 256, 3, 3]   -0.0386     0.323        float32
#    97              model.21.m.0.cv2.bn.weight         BatchNorm2d     False         256               [256]      1.75     0.511        float32
#    97                model.21.m.0.cv2.bn.bias         BatchNorm2d     False         256               [256]    -0.975      1.36        float32
#    98            model.22.cv2.0.0.conv.weight              Conv2d     False       73728     [64, 128, 3, 3]   -0.0484     0.442        float32
#    99              model.22.cv2.0.0.bn.weight         BatchNorm2d     False          64                [64]      1.25     0.488        float32
#    99                model.22.cv2.0.0.bn.bias         BatchNorm2d     False          64                [64]   -0.0306      1.29        float32
#   100            model.22.cv2.0.1.conv.weight              Conv2d     False       36864      [64, 64, 3, 3]   -0.0614     0.455        float32
#   101              model.22.cv2.0.1.bn.weight         BatchNorm2d     False          64                [64]       1.3     0.851        float32
#   101                model.22.cv2.0.1.bn.bias         BatchNorm2d     False          64                [64]    -0.604      1.03        float32
#   102                 model.22.cv2.0.2.weight              Conv2d     False        4096      [64, 64, 1, 1]    -0.291     0.789        float32
#   102                   model.22.cv2.0.2.bias              Conv2d     False          64                [64]     0.829      1.66        float32
#   103            model.22.cv2.1.0.conv.weight              Conv2d     False      147456     [64, 256, 3, 3]   -0.0258     0.372        float32
#   104              model.22.cv2.1.0.bn.weight         BatchNorm2d     False          64                [64]      1.39     0.512        float32
#   104                model.22.cv2.1.0.bn.bias         BatchNorm2d     False          64                [64]    -0.113      1.51        float32
#   105            model.22.cv2.1.1.conv.weight              Conv2d     False       36864      [64, 64, 3, 3]   -0.0537     0.427        float32
#   106              model.22.cv2.1.1.bn.weight         BatchNorm2d     False          64                [64]      1.35     0.754        float32
#   106                model.22.cv2.1.1.bn.bias         BatchNorm2d     False          64                [64]    -0.654      1.28        float32
#   107                 model.22.cv2.1.2.weight              Conv2d     False        4096      [64, 64, 1, 1]    -0.298     0.755        float32
#   107                   model.22.cv2.1.2.bias              Conv2d     False          64                [64]     0.925       1.5        float32
#   108            model.22.cv2.2.0.conv.weight              Conv2d     False      294912     [64, 512, 3, 3]   -0.0217     0.286        float32
#   109              model.22.cv2.2.0.bn.weight         BatchNorm2d     False          64                [64]      1.84     0.573        float32
#   109                model.22.cv2.2.0.bn.bias         BatchNorm2d     False          64                [64]    -0.378      1.42        float32
#   110            model.22.cv2.2.1.conv.weight              Conv2d     False       36864      [64, 64, 3, 3]   -0.0361     0.414        float32
#   111              model.22.cv2.2.1.bn.weight         BatchNorm2d     False          64                [64]      1.62     0.783        float32
#   111                model.22.cv2.2.1.bn.bias         BatchNorm2d     False          64                [64]    -0.716      1.39        float32
#   112                 model.22.cv2.2.2.weight              Conv2d     False        4096      [64, 64, 1, 1]     -0.23     0.706        float32
#   112                   model.22.cv2.2.2.bias              Conv2d     False          64                [64]     0.856      1.75        float32
#   113            model.22.cv3.0.0.conv.weight              Conv2d     False      147456    [128, 128, 3, 3]   -0.0522     0.384        float32
#   114              model.22.cv3.0.0.bn.weight         BatchNorm2d     False         128               [128]     0.964     0.349        float32
#   114                model.22.cv3.0.0.bn.bias         BatchNorm2d     False         128               [128]      -1.1      1.18        float32
#   115            model.22.cv3.0.1.conv.weight              Conv2d     False      147456    [128, 128, 3, 3]   -0.0466     0.284        float32
#   116              model.22.cv3.0.1.bn.weight         BatchNorm2d     False         128               [128]      2.49      1.03        float32
#   116                model.22.cv3.0.1.bn.bias         BatchNorm2d     False         128               [128]    -0.224      2.07        float32
#   117                 model.22.cv3.0.2.weight              Conv2d     False         384      [3, 128, 1, 1]   -0.0941     0.269        float32
#   117                   model.22.cv3.0.2.bias              Conv2d     False           3                 [3]      -8.1     0.758        float32
#   118            model.22.cv3.1.0.conv.weight              Conv2d     False      294912    [128, 256, 3, 3]   -0.0342     0.334        float32
#   119              model.22.cv3.1.0.bn.weight         BatchNorm2d     False         128               [128]       1.1     0.417        float32
#   119                model.22.cv3.1.0.bn.bias         BatchNorm2d     False         128               [128]     -1.14      1.47        float32
#   120            model.22.cv3.1.1.conv.weight              Conv2d     False      147456    [128, 128, 3, 3]   -0.0385     0.285        float32
#   121              model.22.cv3.1.1.bn.weight         BatchNorm2d     False         128               [128]      2.37      1.35        float32
#   121                model.22.cv3.1.1.bn.bias         BatchNorm2d     False         128               [128]    -0.155      1.58        float32
#   122                 model.22.cv3.1.2.weight              Conv2d     False         384      [3, 128, 1, 1]    -0.119     0.293        float32
#   122                   model.22.cv3.1.2.bias              Conv2d     False           3                 [3]     -6.96     0.442        float32
#   123            model.22.cv3.2.0.conv.weight              Conv2d     False      589824    [128, 512, 3, 3]   -0.0191       0.3        float32
#   124              model.22.cv3.2.0.bn.weight         BatchNorm2d     False         128               [128]      1.19     0.691        float32
#   124                model.22.cv3.2.0.bn.bias         BatchNorm2d     False         128               [128]    -0.947      1.48        float32
#   125            model.22.cv3.2.1.conv.weight              Conv2d     False      147456    [128, 128, 3, 3]   -0.0221      0.28        float32
#   126              model.22.cv3.2.1.bn.weight         BatchNorm2d     False         128               [128]      3.17      1.18        float32
#   126                model.22.cv3.2.1.bn.bias         BatchNorm2d     False         128               [128]      -1.3      1.83        float32
#   127                 model.22.cv3.2.2.weight              Conv2d     False         384      [3, 128, 1, 1]   -0.0588      0.37        float32
#   127                   model.22.cv3.2.2.bias              Conv2d     False           3                 [3]     -6.77      1.72        float32
#   128                model.22.dfl.conv.weight              Conv2d     False          16       [1, 16, 1, 1]       7.5      4.76        float32
# Model summary: 129 layers, 11,136,761 parameters, 0 gradients, 28.7 GFLOPs
# (129, 11136761, 0, 28.651263999999998)

# %% [markdown]
# ## Export Class Names to JSON
# Save the class labels for use in other parts of the project:

# %%
import json
from pathlib import Path

# Export class names to JSON
output_path = Path(MODEL_PATH).stem + "_classes.json"
with open(output_path, 'w') as f:
    json.dump(model.names, f, indent=2)
    
print(f"✅ Class names exported to: {output_path}")
print(f"\nContent:")
print(json.dumps(model.names, indent=2))
